# %%
import numpy
import matplotlib.pyplot
data = numpy.loadtxt(fname='important_message.csv', delimiter=",")

# %%
print(data[...])
# print(data[:,0], data[:,1])
# Out:
# [[  1.1292  275.5    ]
#  [  1.1128  260.43   ]
#  [  0.7995   99.428  ]
#  ...
#  [498.65     -0.87421]
#  [500.31     -0.87227]
#  [501.69     -0.87065]]

# %%
ave_important=numpy.mean(data,axis=0)
ave_plot = matplotlib.pyplot.plot(ave_important)
matplotlib.pyplot.show()

# %%
ave_important2=data
Mia_plot = matplotlib.pyplot.plot(data[:,1], data[:,0], ".", color='pink')
matplotlib.pyplot.show()
